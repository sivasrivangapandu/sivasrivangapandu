# %% [markdown]
# <a href="https://colab.research.google.com/github/sivasrivangapandu/sivasrivangapandu/blob/main/experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
dataset=pd.read_csv("/content/age_salary_dataset (1).csv")

print('independent variable(x):',x)
print('dependent varaible(y):',y)
# Out:
# independent variable(x): [[50.        ]
#  [36.        ]
#  [29.        ]
#  [42.        ]
#  [40.        ]
#  [44.        ]
#  [32.        ]
#  [32.        ]
#  [45.        ]
#  [57.        ]
#  [45.        ]
#  [24.        ]
#  [43.        ]
#  [23.        ]
#  [45.        ]
#  [51.        ]
#  [59.        ]
#  [23.        ]
#  [42.        ]
#  [54.        ]
#  [33.        ]
#  [43.        ]
#  [39.88659794]
#  [48.        ]
#  [49.        ]
#  [37.        ]
#  [36.        ]
#  [24.        ]
#  [58.        ]
#  [28.        ]
#  [42.        ]
#  [30.        ]
#  [39.        ]
#  [25.        ]
#  [46.        ]
#  [39.88659794]
#  [30.        ]
#  [47.        ]
#  [23.        ]
#  [41.        ]
#  [49.        ]
#  [28.        ]
#  [29.        ]
#  [39.88659794]
#  [35.        ]
#  [38.        ]
#  [57.        ]
#  [25.        ]
#  [23.        ]
#  [27.        ]
#  [25.        ]
#  [50.        ]
#  [39.        ]
#  [47.        ]
#  [55.        ]
#  [31.        ]
#  [57.        ]
# ...

# %%
x=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]
print(x)
print(y)
# Out:
#      Age
# 0   50.0
# 1   36.0
# 2   29.0
# 3   42.0
# 4   40.0
# ..   ...
# 95  58.0
# 96  56.0
# 97  43.0
# 98  48.0
# 99  56.0
#
# [100 rows x 1 columns]
# 0     45056.0
# 1     72482.0
# 2     87716.0
# 3     48110.0
# 4     53773.0
#        ...
# 95    57675.0
# 96    92733.0
# 97    84417.0
# 98    63938.0
# 99    63664.0
# Name: Salary, Length: 100, dtype: float64

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy="mean")
x=imp.fit_transform(x)
# Convert y to a NumPy array
y = y.to_numpy()

# Reshape y
y = y.reshape(-1, 1)

# Impute missing values in y
y = imp.fit_transform(y)

# Flatten y
y = y.reshape(-1)

# Print x and y
print(x)
print(y)
# Out:
# [[50.        ]
#  [36.        ]
#  [29.        ]
#  [42.        ]
#  [40.        ]
#  [44.        ]
#  [32.        ]
#  [32.        ]
#  [45.        ]
#  [57.        ]
#  [45.        ]
#  [24.        ]
#  [43.        ]
#  [23.        ]
#  [45.        ]
#  [51.        ]
#  [59.        ]
#  [23.        ]
#  [42.        ]
#  [54.        ]
#  [33.        ]
#  [43.        ]
#  [39.88659794]
#  [48.        ]
#  [49.        ]
#  [37.        ]
#  [36.        ]
#  [24.        ]
#  [58.        ]
#  [28.        ]
#  [42.        ]
#  [30.        ]
#  [39.        ]
#  [25.        ]
#  [46.        ]
#  [39.88659794]
#  [30.        ]
#  [47.        ]
#  [23.        ]
#  [41.        ]
#  [49.        ]
#  [28.        ]
#  [29.        ]
#  [39.88659794]
#  [35.        ]
#  [38.        ]
#  [57.        ]
#  [25.        ]
#  [23.        ]
#  [27.        ]
#  [25.        ]
#  [50.        ]
#  [39.        ]
#  [47.        ]
#  [55.        ]
#  [31.        ]
#  [57.        ]
#  [35.        ]
# ...

# %%
x_df=pd.DataFrame(x,columns=dataset.columns[:-1])
y_df=pd.DataFrame(y,columns=[dataset.columns[-1]])
combined_data=pd.concat([x_df,y_df],axis=1)
print("Combined Data:")
print(combined_data)
# Out:
# Combined Data:
#      Age   Salary
# 0   50.0  45056.0
# 1   36.0  72482.0
# 2   29.0  87716.0
# 3   42.0  48110.0
# 4   40.0  53773.0
# ..   ...      ...
# 95  58.0  57675.0
# 96  56.0  92733.0
# 97  43.0  84417.0
# 98  48.0  63938.0
# 99  56.0  63664.0
#
# [100 rows x 2 columns]

# %%
combined_df=pd.DataFrame(combined_data,columns=list(dataset.columns))
combined_df.to_excel("/content/combined_data.xlsx",index=False)
#print("Combined DatFrame:")
#print(combined_df.head())

# %% [markdown]
# # New Section
